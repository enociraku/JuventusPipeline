# %%
import io
import requests
import pandas as pd


file_url = 'https://www.football-data.co.uk/mmz4281/9394/I1.csv'
urlData = requests.get(file_url).content
rawData = pd.read_csv(io.StringIO(urlData.decode('utf-8')))

# cleanData has only important columns and no NULL values in any column or row
cleanData = rawData[["Div", "HomeTeam", "AwayTeam", "FTHG", "FTAG", "FTR"]].dropna()

# filter only data for Juventus (playing either away or home)
juventusData = cleanData[(cleanData["HomeTeam"] == 'Juventus') | (cleanData["AwayTeam"] == 'Juventus')]
juventusData
# Out:
#     Div   HomeTeam   AwayTeam  FTHG  FTAG FTR
# 3    I1   Juventus  Cremonese   1.0   0.0   H
# 15   I1       Roma   Juventus   2.0   1.0   H
# 21   I1   Juventus  Sampdoria   3.0   1.0   H
# 29   I1     Foggia   Juventus   1.0   1.0   D
# 39   I1   Juventus   Reggiana   4.0   0.0   H
# 48   I1      Lecce   Juventus   1.0   1.0   D
# 56   I1   Juventus     Torino   3.0   2.0   H
# 67   I1   Juventus   Atalanta   2.0   1.0   H
# 75   I1      Milan   Juventus   1.0   1.0   D
# 84   I1   Juventus      Genoa   4.0   0.0   H
# 94   I1      Parma   Juventus   2.0   0.0   H
# 102  I1   Juventus   Cagliari   1.0   1.0   D
# 109  I1      Inter   Juventus   2.0   2.0   D
# 121  I1   Juventus     Napoli   1.0   0.0   H
# 129  I1      Lazio   Juventus   3.0   1.0   H
# 138  I1   Juventus   Piacenza   2.0   0.0   H
# 152  I1    Udinese   Juventus   0.0   3.0   A
# 154  I1  Cremonese   Juventus   1.0   1.0   D
# 165  I1   Juventus       Roma   0.0   0.0   D
# 178  I1  Sampdoria   Juventus   1.0   1.0   D
# 183  I1   Juventus     Foggia   2.0   0.0   H
# 194  I1   Reggiana   Juventus   0.0   0.0   D
# 201  I1   Juventus      Lecce   5.0   1.0   H
# 215  I1     Torino   Juventus   1.0   1.0   D
# 216  I1   Atalanta   Juventus   1.0   3.0   A
# 228  I1   Juventus      Milan   0.0   1.0   A
# 236  I1      Genoa   Juventus   1.0   1.0   D
# 246  I1   Juventus      Parma   4.0   0.0   H
# 252  I1   Cagliari   Juventus   0.0   1.0   A
# 265  I1   Juventus      Inter   1.0   0.0   H
# 273  I1     Napoli   Juventus   0.0   0.0   D
# 282  I1   Juventus      Lazio   6.0   1.0   H
# 293  I1   Piacenza   Juventus   0.0   0.0   D
# 300  I1   Juventus    Udinese   1.0   0.0   H

# %%
juventusHomeWinningData = juventusData[(juventusData["HomeTeam"] == 'Juventus') & (juventusData["FTR"] == 'H')]
juventusHomeWinningData
# Out:
#     Div  HomeTeam   AwayTeam  FTHG  FTAG FTR
# 3    I1  Juventus  Cremonese   1.0   0.0   H
# 21   I1  Juventus  Sampdoria   3.0   1.0   H
# 39   I1  Juventus   Reggiana   4.0   0.0   H
# 56   I1  Juventus     Torino   3.0   2.0   H
# 67   I1  Juventus   Atalanta   2.0   1.0   H
# 84   I1  Juventus      Genoa   4.0   0.0   H
# 121  I1  Juventus     Napoli   1.0   0.0   H
# 138  I1  Juventus   Piacenza   2.0   0.0   H
# 183  I1  Juventus     Foggia   2.0   0.0   H
# 201  I1  Juventus      Lecce   5.0   1.0   H
# 246  I1  Juventus      Parma   4.0   0.0   H
# 265  I1  Juventus      Inter   1.0   0.0   H
# 282  I1  Juventus      Lazio   6.0   1.0   H
# 300  I1  Juventus    Udinese   1.0   0.0   H

# %%
juventusAwayWinningData = juventusData[(juventusData["AwayTeam"] == 'Juventus') & (juventusData["FTR"] == 'A')]
juventusAwayWinningData
# Out:
#     Div  HomeTeam  AwayTeam  FTHG  FTAG FTR
# 152  I1   Udinese  Juventus   0.0   3.0   A
# 216  I1  Atalanta  Juventus   1.0   3.0   A
# 252  I1  Cagliari  Juventus   0.0   1.0   A

# %%
juventusWinningData = juventusData[((juventusData["HomeTeam"] == 'Juventus') & (juventusData["FTR"] == 'H')) | ((juventusData["AwayTeam"] == 'Juventus') & (juventusData["FTR"] == 'A'))]
juventusWinningData
# Out:
#     Div  HomeTeam   AwayTeam  FTHG  FTAG FTR
# 3    I1  Juventus  Cremonese   1.0   0.0   H
# 21   I1  Juventus  Sampdoria   3.0   1.0   H
# 39   I1  Juventus   Reggiana   4.0   0.0   H
# 56   I1  Juventus     Torino   3.0   2.0   H
# 67   I1  Juventus   Atalanta   2.0   1.0   H
# 84   I1  Juventus      Genoa   4.0   0.0   H
# 121  I1  Juventus     Napoli   1.0   0.0   H
# 138  I1  Juventus   Piacenza   2.0   0.0   H
# 152  I1   Udinese   Juventus   0.0   3.0   A
# 183  I1  Juventus     Foggia   2.0   0.0   H
# 201  I1  Juventus      Lecce   5.0   1.0   H
# 216  I1  Atalanta   Juventus   1.0   3.0   A
# 246  I1  Juventus      Parma   4.0   0.0   H
# 252  I1  Cagliari   Juventus   0.0   1.0   A
# 265  I1  Juventus      Inter   1.0   0.0   H
# 282  I1  Juventus      Lazio   6.0   1.0   H
# 300  I1  Juventus    Udinese   1.0   0.0   H
